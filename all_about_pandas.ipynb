# %%
 import pandas as pd

# %%
csv = pd.read_csv('../data/survey_results_public.csv')
data = pd.read_csv('../data/survey_results_schema.csv')

csv.set_index('ResponseId', inplace = True)

# %%
csv.tail(5)
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 89180       I agree  I am a developer by profession     25-34 years old
# 89181       I agree  I am a developer by profession     18-24 years old
# 89182       I agree     I code primarily as a hobby   Prefer not to say
# 89183       I agree  I am a developer by profession  Under 18 years old
# 89184       I agree  I am a developer by profession     35-44 years old
#
#                                                    Employment  \
# ResponseId
# 89180       Employed, full-time;Independent contractor, fr...
# 89181                  Student, full-time;Employed, part-time
# 89182                                     I prefer not to say
# 89183                  Employed, part-time;Student, part-time
# 89184                                     Employed, full-time
#
#                                       RemoteWork  \
# ResponseId
# 89180                                     Remote
# ...

# %%
csv.head(5)
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 1           I agree                   None of these  18-24 years old
# 2           I agree  I am a developer by profession  25-34 years old
# 3           I agree  I am a developer by profession  45-54 years old
# 4           I agree  I am a developer by profession  25-34 years old
# 5           I agree  I am a developer by profession  25-34 years old
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# 3                                         Employed, full-time
# 4                                         Employed, full-time
# 5           Employed, full-time;Independent contractor, fr...
#
#                                       RemoteWork  \
# ResponseId
# 1                                            NaN
# ...

# %%
csv.columns
# Out:
# Index(['Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
#        'OfficeStackSyncWantToWorkWith', 'AISearchHaveWorkedWith',
# ...

# %%
csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 89184 entries, 1 to 89184
# Data columns (total 83 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Q120                                 89184 non-null  object
#  1   MainBranch                           89184 non-null  object
#  2   Age                                  89184 non-null  object
#  3   Employment                           87898 non-null  object
#  4   RemoteWork                           73810 non-null  object
#  5   CodingActivities                     73764 non-null  object
#  6   EdLevel                              87973 non-null  object
#  7   LearnCode                            87663 non-null  object
#  8   LearnCodeOnline                      70084 non-null  object
#  9   LearnCodeCoursesCert                 37076 non-null  object
#  10  YearsCode                            87435 non-null  object
# ...

# %%
csv.describe() # statistics
# Out:
#           CompTotal       WorkExp  ConvertedCompYearly
# count  4.822500e+04  43579.000000         4.801900e+04
# mean   1.036807e+42     11.405126         1.031101e+05
# std    2.276847e+44      9.051989         6.814188e+05
# min    0.000000e+00      0.000000         1.000000e+00
# 25%    6.300000e+04      5.000000         4.390700e+04
# 50%    1.150000e+05      9.000000         7.496300e+04
# 75%    2.300000e+05     16.000000         1.216410e+05
# max    5.000000e+46     50.000000         7.435143e+07

# %%
csv.shape
# Out:
# (89184, 83)

# %%
data.head()
# Out:
#       qid     qname                                           question  \
# 0   QID16        S0  <div><span style="font-size:19px;"><strong>Hel...
# 1   QID12  MetaInfo                                  Browser Meta Info
# 2  QID310      Q310  <div><span style="font-size:19px;"><strong>You...
# 3  QID312      Q120
# 4    QID1        S1  <span style="font-size:22px; font-family: aria...
#
#   force_resp  type selector
# 0      False    DB       TB
# 1      False  Meta  Browser
# 2      False    DB       TB
# 3       True    MC     SAVR
# 4      False    DB       TB

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   qid         78 non-null     object
#  1   qname       78 non-null     object
#  2   question    78 non-null     object
#  3   force_resp  67 non-null     object
#  4   type        78 non-null     object
#  5   selector    78 non-null     object
# dtypes: object(6)
# memory usage: 3.8+ KB

# %% [markdown]
# ##### Creating a new DataFrame

# %%
data = {
    "name":["A","b","c"],
    "age":[23,33,25.0],
    "gender":["M","F",None]
}

dataframe = pd.DataFrame(data)

# %%
dataframe
# Out:
#   name   age gender
# 0    A  23.0      M
# 1    b  33.0      F
# 2    c  25.0   None

# %%
dataframe['age'] = dataframe['age'].astype(int)

# %%
dataframe['age'] # returns a series
# Out:
# 0    23
# 1    33
# 2    25
# Name: age, dtype: int32

# %%
dataframe[['age','gender']] # returns a df
# Out:
#    age gender
# 0   23      M
# 1   33      F
# 2   25   None

# %%
csv['RemoteWork'].value_counts() #returns the count of each unique value in the column
# Out:
# Hybrid (some remote, some in-person)    31131
# Remote                                  30566
# In-person                               12113
# Name: RemoteWork, dtype: int64

# %%
dataframe.set_index('name') # setting the index as name
# Out:
#       age gender
# name
# A      23      M
# b      33      F
# c      25   None

# %%
#create a new dataframe 
data = {
    "gender":["m","f","m","m","f"],
    "name":["a","b","v","d","e"],
    "height":[123,123,1245,354,344]
}
new = pd.DataFrame(data)
new
# Out:
#   gender name  height
# 0      m    a     123
# 1      f    b     123
# 2      m    v    1245
# 3      m    d     354
# 4      f    e     344

# %%
new['height'].mean() #mean of a particular column
# Out:
# 437.8

# %%
new[new['gender'] == "f"] # Masking and Filtering
# Out:
#   gender name  height
# 1      f    b     123
# 4      f    e     344

# %%
new[new['gender'] == "f"]['height'].mean() #new[new['gender'] == "f"] is our new filtered df here
# Out:
# 233.5

# %%
new[new['gender'] == "f"].mean()
# Out:
# C:\Users\prami\AppData\Local\Temp\ipykernel_60400\2367395597.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   new[new['gender'] == "f"].mean()
# height    233.5
# dtype: float64

# %% [markdown]
# ##### Masking

# %%
new["gender"]=="m" # this is called a mask for the df
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4    False
# Name: gender, dtype: bool

# %%
mask = (new["gender"] == "m") & (new["name"] == "a")

# %% [markdown]
# ##### Filtering

# %%
# FILTER OUT
new[mask]
# Out:
#   gender name  height
# 0      m    a     123

# %%
# INVERTED MASK
new[~mask]
# Out:
#   gender name  height
# 1      f    b     123
# 2      m    v    1245
# 3      m    d     354
# 4      f    e     344

# %%
passed_names = ["b","d"]
new[new["name"].isin(passed_names)]
# Out:
#   gender name  height
# 1      f    b     123
# 3      m    d     354

# %%
# Equivalent of above
new[(new["name"] == "b") | (new["name"] == "d")]
# Out:
#   gender name  height
# 1      f    b     123
# 3      m    d     354

# %%
new[new['height']>300] #filtering numeric column
# Out:
#   gender name  height
# 2      m    v    1245
# 3      m    d     354
# 4      f    e     344

# %%
csv["LanguageHaveWorkedWith"] #csv dataframe
# Out:
# ResponseId
# 1                                                      NaN
# 2                               HTML/CSS;JavaScript;Python
# 3                               Bash/Shell (all shells);Go
# 4        Bash/Shell (all shells);HTML/CSS;JavaScript;PH...
# 5                           HTML/CSS;JavaScript;TypeScript
#                                ...
# 89180              HTML/CSS;Java;JavaScript;SQL;TypeScript
# 89181                                 Dart;Java;Python;SQL
# 89182    Assembly;Bash/Shell (all shells);C;C#;Python;R...
# 89183    Bash/Shell (all shells);C#;HTML/CSS;Java;JavaS...
# 89184                      C#;Go;JavaScript;SQL;TypeScript
# Name: LanguageHaveWorkedWith, Length: 89184, dtype: object

# %%
csv[csv["LanguageHaveWorkedWith"].str.contains("Python", na = False)].head() # https://pandas.pydata.org/docs/reference/api/pandas.Series.str.contains.html
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 2           I agree  I am a developer by profession  25-34 years old
# 8           I agree  I am a developer by profession  25-34 years old
# 10          I agree  I am a developer by profession  25-34 years old
# 11          I agree  I am a developer by profession  25-34 years old
# 12          I agree  I am a developer by profession  25-34 years old
#
#                                     Employment RemoteWork  \
# ResponseId
# 2                          Employed, full-time     Remote
# 8                          Employed, full-time     Remote
# 10          Not employed, but looking for work        NaN
# 11                         Employed, full-time     Remote
# 12                         Employed, full-time     Remote
#
#                                              CodingActivities  \
# ResponseId
# 2           Hobby;Contribute to open-source projects;Boots...
# ...

# %%
cols = list(new.columns)
cols = [el.upper() for el in cols ] 
#bad deril shouted at me

# %%
new.columns = cols 
# renaming the column names
print(new.columns)
# Out:
# Index(['GENDER', 'NAME', 'HEIGHT'], dtype='object')

# %%
# creating new cols in df
new['all_same'] = 2
new
# Out:
#   GENDER NAME  HEIGHT  all_same
# 0      m    a     123         2
# 1      f    b     123         2
# 2      m    v    1245         2
# 3      m    d     354         2
# 4      f    e     344         2

# %%
new['gh'] = new['GENDER'] + new['HEIGHT'].astype(str) + '_gh' # creating new columns using the existing ones
new
# Out:
#   GENDER NAME  HEIGHT  all_same        gh
# 0      m    a     123         2   m123_gh
# 1      f    b     123         2   f123_gh
# 2      m    v    1245         2  m1245_gh
# 3      m    d     354         2   m354_gh
# 4      f    e     344         2   f344_gh

# %%
new.drop(columns = ['gh', 'all_same'], inplace = True) #dropping columns
new
# Out:
#   GENDER NAME  HEIGHT
# 0      m    a     123
# 1      f    b     123
# 2      m    v    1245
# 3      m    d     354
# 4      f    e     344

# %%
new['gh'] = new['GENDER'] + " " + new['HEIGHT'].astype(str) 
new
# Out:
#   GENDER NAME  HEIGHT      gh
# 0      m    a     123   m 123
# 1      f    b     123   f 123
# 2      m    v    1245  m 1245
# 3      m    d     354   m 354
# 4      f    e     344   f 344

# %%
#splitting gh on the basis on space

new['gh'].str.split(" ")
# Out:
# 0     [m, 123]
# 1     [f, 123]
# 2    [m, 1245]
# 3     [m, 354]
# 4     [f, 344]
# Name: gh, dtype: object

# %%
new['gh'].apply(lambda x : x.split(" ")) #same as above
# Out:
# 0     [m, 123]
# 1     [f, 123]
# 2    [m, 1245]
# 3     [m, 354]
# 4     [f, 344]
# Name: gh, dtype: object

# %%
new['gh'] = new['GENDER'] + "|" + new['HEIGHT'].astype(str)
new
# Out:
#   GENDER NAME  HEIGHT      gh
# 0      m    a     123   m|123
# 1      f    b     123   f|123
# 2      m    v    1245  m|1245
# 3      m    d     354   m|354
# 4      f    e     344   f|344

# %%
#splitting gh on the basis on space

new['gh'].str.split("|")
# Out:
# 0     [m, 123]
# 1     [f, 123]
# 2    [m, 1245]
# 3     [m, 354]
# 4     [f, 344]
# Name: gh, dtype: object

# %%
new['gh'].str.split("|", expand = True) # expand gives in dataframe instead of a list
# Out:
#    0     1
# 0  m   123
# 1  f   123
# 2  m  1245
# 3  m   354
# 4  f   344

# %%
new[['new_gender', 'new_height']] = new['gh'].str.split("|", expand = True)
new
#important
# new columns, expand
# Out:
#   GENDER NAME  HEIGHT      gh new_gender new_height
# 0      m    a     123   m|123          m        123
# 1      f    b     123   f|123          f        123
# 2      m    v    1245  m|1245          m       1245
# 3      m    d     354   m|354          m        354
# 4      f    e     344   f|344          f        344

# %%
new.drop(0) #defualt axis=0 in pandas is rows and in numpy is columns
# Out:
#   GENDER NAME  HEIGHT      gh new_gender new_height
# 1      f    b     123   f|123          f        123
# 2      m    v    1245  m|1245          m       1245
# 3      m    d     354   m|354          m        354
# 4      f    e     344   f|344          f        344

# %%
new.drop('gh', axis = 1, inplace = True) 
#if axis = 0 then it affects on index 
#axis =1 affcts columns
new
# Out:
#   GENDER NAME  HEIGHT new_gender new_height
# 0      m    a     123          m        123
# 1      f    b     123          f        123
# 2      m    v    1245          m       1245
# 3      m    d     354          m        354
# 4      f    e     344          f        344

# %%
new.append({'GENDER': 'm', 'NAME': 'deril'}, ignore_index = True)
# Out:
# C:\Users\prami\AppData\Local\Temp\ipykernel_60400\2817610015.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new.append({'GENDER': 'm', 'NAME': 'deril'}, ignore_index = True)
#   GENDER   NAME  HEIGHT      gh
# 0      m      a   123.0   m 123
# 1      f      b   123.0   f 123
# 2      m      v  1245.0  m 1245
# 3      m      d   354.0   m 354
# 4      f      e   344.0   f 344
# 5      m  deril     NaN     NaN

# %%
new.append(new, ignore_index= True)
# Out:
# C:\Users\prami\AppData\Local\Temp\ipykernel_60400\2570743164.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new.append(new, ignore_index= True)
#   GENDER NAME  HEIGHT      gh
# 0      m    a     123   m 123
# 1      f    b     123   f 123
# 2      m    v    1245  m 1245
# 3      m    d     354   m 354
# 4      f    e     344   f 344
# 5      m    a     123   m 123
# 6      f    b     123   f 123
# 7      m    v    1245  m 1245
# 8      m    d     354   m 354
# 9      f    e     344   f 344

# %% [markdown]
# ##### Sorting

# %%
new[['new_height','HEIGHT']]= new[['new_height','HEIGHT']].astype(int)
new.sort_values(by = 'new_height', ascending= True)
# Out:
#   GENDER NAME  HEIGHT new_gender  new_height
# 0      m    a     123          m         123
# 1      f    b     123          f         123
# 4      f    e     344          f         344
# 3      m    d     354          m         354
# 2      m    v    1245          m        1245

# %%
new.sort_values(by = ['new_height','HEIGHT'], ascending= [True,False])
#If you want to sort 2 columns, one after the other, and the order is different then u can use ascending= [True,False] according to ur requirements
# its always in the ratio
# Out:
#   GENDER NAME  HEIGHT new_gender  new_height
# 0      m    a     123          m         123
# 1      f    b     123          f         123
# 4      f    e     344          f         344
# 3      m    d     354          m         354
# 2      m    v    1245          m        1245

# %% [markdown]
# ## Group By

# %%
csv
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 1           I agree                   None of these     18-24 years old
# 2           I agree  I am a developer by profession     25-34 years old
# 3           I agree  I am a developer by profession     45-54 years old
# 4           I agree  I am a developer by profession     25-34 years old
# 5           I agree  I am a developer by profession     25-34 years old
# ...             ...                             ...                 ...
# 89180       I agree  I am a developer by profession     25-34 years old
# 89181       I agree  I am a developer by profession     18-24 years old
# 89182       I agree     I code primarily as a hobby   Prefer not to say
# 89183       I agree  I am a developer by profession  Under 18 years old
# 89184       I agree  I am a developer by profession     35-44 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %%
 csv["ConvertedCompYearly"].mean()
# Out:
# 103110.08171765343

# %%
 csv["ConvertedCompYearly"].median()
# Out:
# 74963.0

# %%
csv.median() # median of all numerical columns
# Out:
# C:\Users\prami\AppData\Local\Temp\ipykernel_60400\1044457711.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   csv.median()
# CompTotal              115000.0
# WorkExp                     9.0
# ConvertedCompYearly     74963.0
# dtype: float64

# %%
if "Hobbyist" in csv.columns:
    print(True)
else:
    print(False) #checking if hobbyist column is present in the df
# Out:
# False

# %%
csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 89184 entries, 1 to 89184
# Data columns (total 83 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Q120                                 89184 non-null  object
#  1   MainBranch                           89184 non-null  object
#  2   Age                                  89184 non-null  object
#  3   Employment                           87898 non-null  object
#  4   RemoteWork                           73810 non-null  object
#  5   CodingActivities                     73764 non-null  object
#  6   EdLevel                              87973 non-null  object
#  7   LearnCode                            87663 non-null  object
#  8   LearnCodeOnline                      70084 non-null  object
#  9   LearnCodeCoursesCert                 37076 non-null  object
#  10  YearsCode                            87435 non-null  object
# ...

# %%
csv["Country"].value_counts()
# Out:
# United States of America                                18647
# Germany                                                  7328
# India                                                    5625
# United Kingdom of Great Britain and Northern Ireland     5552
# Canada                                                   3507
#                                                         ...
# Saint Kitts and Nevis                                       1
# Marshall Islands                                            1
# Samoa                                                       1
# Central African Republic                                    1
# San Marino                                                  1
# Name: Country, Length: 185, dtype: int64

# %%
csv[csv["Country"] == "United States of America"]
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 2           I agree                     I am a developer by profession
# 3           I agree                     I am a developer by profession
# 4           I agree                     I am a developer by profession
# 7           I agree                     I am a developer by profession
# 8           I agree                     I am a developer by profession
# ...             ...                                                ...
# 89151       I agree  I used to be a developer by profession, but no...
# 89155       I agree                     I am a developer by profession
# 89157       I agree                     I am a developer by profession
# 89176       I agree                     I am a developer by profession
# 89179       I agree                     I am a developer by profession
#
#                         Age           Employment  \
# ResponseId
# ...

# %%
country_group =  csv.groupby(["Country"])

# %%
country_group

# %%
country_group.get_group("India")
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 10          I agree                     I am a developer by profession
# 67          I agree                     I am a developer by profession
# 79          I agree                     I am a developer by profession
# 83          I agree                     I am a developer by profession
# 86          I agree                     I am a developer by profession
# ...             ...                                                ...
# 89120       I agree                     I am a developer by profession
# 89122       I agree  I am not primarily a developer, but I write co...
# 89165       I agree                     I am a developer by profession
# 89166       I agree                     I am a developer by profession
# 89168       I agree                     I am a developer by profession
#
#                         Age                              Employment  \
# ResponseId
# ...

# %%
# Equivalent of above
csv[csv["Country"]=="India"]
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 10          I agree                     I am a developer by profession
# 67          I agree                     I am a developer by profession
# 79          I agree                     I am a developer by profession
# 83          I agree                     I am a developer by profession
# 86          I agree                     I am a developer by profession
# ...             ...                                                ...
# 89120       I agree                     I am a developer by profession
# 89122       I agree  I am not primarily a developer, but I write co...
# 89165       I agree                     I am a developer by profession
# 89166       I agree                     I am a developer by profession
# 89168       I agree                     I am a developer by profession
#
#                         Age                              Employment  \
# ResponseId
# ...

# %%
csv["ConvertedCompYearly"].mean() # full dataset salary mean

# give me salary mean only for India
csv[csv["Country"]=="India"]["ConvertedCompYearly"].mean()
# Out:
# 27346.822805139185

# %%
(csv["Country"]=="India").sum()
# Out:
# 5625

# %%
country_group =  csv.groupby(["Country"])
country_group["RemoteWork"].value_counts().head(50)
# Out:
# Country              RemoteWork
# Afghanistan          Hybrid (some remote, some in-person)     17
#                      Remote                                   17
#                      In-person                                 8
# Albania              Hybrid (some remote, some in-person)     18
#                      In-person                                17
#                      Remote                                   15
# Algeria              Remote                                   27
#                      Hybrid (some remote, some in-person)     12
#                      In-person                                11
# Andorra              In-person                                 6
#                      Remote                                    5
#                      Hybrid (some remote, some in-person)      2
# Angola               Hybrid (some remote, some in-person)      3
#                      In-person                                 3
# ...

# %%
country_group['RemoteWork'].value_counts().loc["India"]
# Out:
# RemoteWork
# Hybrid (some remote, some in-person)    1638
# Remote                                  1405
# In-person                               1104
# Name: RemoteWork, dtype: int64

# %%
country_group['RemoteWork'].value_counts(normalize= True).loc["India"]
# Out:
# RemoteWork
# Hybrid (some remote, some in-person)    0.394984
# Remote                                  0.338799
# In-person                               0.266217
# Name: RemoteWork, dtype: float64

# %%
country_group["ConvertedCompYearly"].mean()
# Out:
# Country
# Afghanistan                             843636.090909
# Albania                                  29219.450000
# Algeria                                  10069.190476
# Andorra                                 120368.800000
# Angola                                    4302.000000
#                                             ...
# Venezuela, Bolivarian Republic of...     23068.851852
# Viet Nam                                 20995.956140
# Yemen                                    15089.333333
# Zambia                                   13897.800000
# Zimbabwe                                 26740.000000
# Name: ConvertedCompYearly, Length: 185, dtype: float64

# %%
country_group["ConvertedCompYearly"].mean().loc["India"]
# Out:
# 27346.822805139185

# %%
csv.columns
# Out:
# Index(['Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
#        'OfficeStackSyncWantToWorkWith', 'AISearchHaveWorkedWith',
# ...

# %% [markdown]
# # Q

# %%
csv["Industry"].value_counts()
# Out:
# Information Services, IT, Software Development, or other Technology    18159
# Financial Services                                                      4421
# Other                                                                   4011
# Manufacturing, Transportation, or Supply Chain                          2607
# Healthcare                                                              2216
# Retail and Consumer Services                                            1955
# Higher Education                                                        1242
# Advertising Services                                                     786
# Insurance                                                                707
# Oil & Gas                                                                276
# Legal Services                                                           210
# Wholesale                                                                184
# Name: Industry, dtype: int64

# %%
industry_grp =  csv.groupby(["Industry"])

# %%
industry_grp["ConvertedCompYearly"].mean().loc["Healthcare"]
# Out:
# 103571.10340775558

# %%
industry_grp["ConvertedCompYearly"].agg(["mean", "median", "count", "sum", "min", "max"])
# Out:
#                                                              mean   median  \
# Industry
# Advertising Services                                112730.652033  82245.0
# Financial Services                                  123977.345539  85000.0
# Healthcare                                          103571.103408  89327.0
# Higher Education                                     72076.873126  62400.0
# Information Services, IT, Software Development,...   94924.338332  68494.0
# Insurance                                           100366.450435  81552.0
# Legal Services                                       88300.562130  75000.0
# Manufacturing, Transportation, or Supply Chain       89943.515242  74963.0
# Oil & Gas                                            88982.888889  74963.0
# Other                                               124288.992366  80317.0
# Retail and Consumer Services                         98211.981959  80317.0
# ...

# %%
industry_grp["LanguageHaveWorkedWith"]

# %%
industry_grp["LanguageHaveWorkedWith"].apply(lambda a : a.str.contains("Python").sum())
# Out:
# Industry
# Advertising Services                                                    371
# Financial Services                                                     1974
# Healthcare                                                             1006
# Higher Education                                                        747
# Information Services, IT, Software Development, or other Technology    8215
# Insurance                                                               238
# Legal Services                                                           88
# Manufacturing, Transportation, or Supply Chain                         1311
# Oil & Gas                                                               150
# Other                                                                  2031
# Retail and Consumer Services                                            787
# Wholesale                                                                77
# Name: LanguageHaveWorkedWith, dtype: int64

# %% [markdown]
# ### What % of people from each country know Python?

# %%
country_group["LanguageHaveWorkedWith"].apply(lambda a : a.str.contains("Python").sum()/a.str.contains("Python").count()*100)
# Out:
# Country
# Afghanistan                             37.931034
# Albania                                 34.545455
# Algeria                                 42.168675
# Andorra                                 33.333333
# Angola                                  36.363636
#                                           ...
# Venezuela, Bolivarian Republic of...    40.776699
# Viet Nam                                45.789474
# Yemen                                   44.444444
# Zambia                                  42.307692
# Zimbabwe                                57.575758
# Name: LanguageHaveWorkedWith, Length: 185, dtype: float64

# %%
data = {
    "gender a":["m","f","m","m","f"],
    "name b":["a","b","v","d","e"],
    "height c":[123,123,1245,354,344]
}
test_df = pd.DataFrame(data)
test_df
# Out:
#   gender a name b  height c
# 0        m      a       123
# 1        f      b       123
# 2        m      v      1245
# 3        m      d       354
# 4        f      e       344

# %%
test_df.columns
for cols in test_df.columns:
    print(cols)
# Out:
# gender a
# name b
# height c

# %%
test_df.columns = [cols.split(" ")[0] for cols in test_df.columns]

# %%
test_df
# Out:
#   gender name  height
# 0      m    a     123
# 1      f    b     123
# 2      m    v    1245
# 3      m    d     354
# 4      f    e     344
