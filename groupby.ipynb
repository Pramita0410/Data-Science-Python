# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
#see inbuilt datasets in seaborn
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic',
#  'anagrams',
#  'anagrams',
#  'anscombe',
#  'anscombe',
#  'attention',
#  'attention',
#  'brain_networks',
#  'brain_networks',
#  'car_crashes',
#  'car_crashes',
#  'diamonds',
#  'diamonds',
#  'dots',
#  'dots',
#  'dowjones',
#  'dowjones',
#  'exercise',
#  'exercise',
#  'flights',
#  'flights',
#  'fmri',
#  'fmri',
#  'geyser',
#  'geyser',
#  'glue',
#  'glue',
#  'healthexp',
#  'healthexp',
#  'iris',
#  'iris',
#  'mpg',
#  'mpg',
#  'penguins',
#  'penguins',
#  'planets',
#  'planets',
#  'seaice',
#  'seaice',
#  'taxis',
#  'taxis',
#  'tips',
#  'tips',
#  'titanic',
#  'titanic',
#  'anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
# ...

# %%
df = sns.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df["sex"].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
sns.countplot(data=df, x="day")
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
sns.kdeplot(data=df, x="total_bill", hue="time")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(data=df, x="total_bill")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(data=df, x="total_bill", hue="day")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(data=df, x="tip", hue="sex")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Density'>

# %%
df["tip"].idxmax()
# Out:
# 170

# %%
df.loc[df["tip"].idxmax()]
# Out:
# total_bill     50.81
# tip             10.0
# sex             Male
# smoker           Yes
# day              Sat
# time          Dinner
# size               3
# Name: 170, dtype: object

# %%
df.loc[[df["tip"].idxmax()]]
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 170       50.81  10.0  Male    Yes  Sat  Dinner     3

# %%
df.loc[[df["tip"].idxmin()]]
# Out:
#     total_bill  tip     sex smoker  day    time  size
# 67        3.07  1.0  Female    Yes  Sat  Dinner     1

# %%
df["percentage"] = (df['tip']/df['total_bill'])*100

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  percentage
# 0         16.99  1.01  Female     No   Sun  Dinner     2    5.944673
# 1         10.34  1.66    Male     No   Sun  Dinner     3   16.054159
# 2         21.01  3.50    Male     No   Sun  Dinner     3   16.658734
# 3         23.68  3.31    Male     No   Sun  Dinner     2   13.978041
# 4         24.59  3.61  Female     No   Sun  Dinner     4   14.680765
# ..          ...   ...     ...    ...   ...     ...   ...         ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3   20.392697
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2    7.358352
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2    8.822232
# 242       17.82  1.75    Male     No   Sat  Dinner     2    9.820426
# 243       18.78  3.00  Female     No  Thur  Dinner     2   15.974441
#
# [244 rows x 8 columns]

# %%
df.loc[[df["percentage"].idxmax()]]
# Out:
#      total_bill   tip   sex smoker  day    time  size  percentage
# 172        7.25  5.15  Male    Yes  Sun  Dinner     2   71.034483

# %%
df.loc[[df["percentage"].idxmin()]]
# Out:
#      total_bill   tip   sex smoker  day    time  size  percentage
# 237       32.83  1.17  Male    Yes  Sat  Dinner     2    3.563814

# %%
sns.kdeplot(data=df, x="percentage", hue="sex")
# Out:
# <AxesSubplot:xlabel='percentage', ylabel='Density'>

# %%
male = df[df['sex']=="Male"]

# %%
male["percentage"].mean()
# Out:
# 15.765054700429744

# %%
df[df["sex"]=="Female"]['percentage'].mean()
# Out:
# 16.649073632892485

# %% [markdown]
# ##### Groupby

# %%
# DF.grouby(['categorical_column'])['numeric_column'].agg(["min", "max", "mean", "median"])

# %%
df.groupby(['day'])["total_bill"].agg(["min", "max", "mean", "median"])
# Out:
#        min    max       mean  median
# day
# Thur  7.51  43.11  17.682742   16.20
# Fri   5.75  40.17  17.151579   15.38
# Sat   3.07  50.81  20.441379   18.24
# Sun   7.25  48.17  21.410000   19.63

# %%
#relabel
df.groupby(['day'])["total_bill"].agg(minimum = "min", maximum = "max", mean = np.mean, median = np.median)
# Out:
#       minimum  maximum       mean  median
# day
# Thur     7.51    43.11  17.682742   16.20
# Fri      5.75    40.17  17.151579   15.38
# Sat      3.07    50.81  20.441379   18.24
# Sun      7.25    48.17  21.410000   19.63

# %%
df.groupby(['day'])["total_bill"].agg("describe")
# Out:
#       count       mean       std   min      25%    50%      75%    max
# day
# Thur   62.0  17.682742  7.886170  7.51  12.4425  16.20  20.1550  43.11
# Fri    19.0  17.151579  8.302660  5.75  12.0950  15.38  21.7500  40.17
# Sat    87.0  20.441379  9.480419  3.07  13.9050  18.24  24.7400  50.81
# Sun    76.0  21.410000  8.832122  7.25  14.9875  19.63  25.5975  48.17

# %%
df.groupby(['day'])["total_bill"].mean()
# Out:
# day
# Thur    17.682742
# Fri     17.151579
# Sat     20.441379
# Sun     21.410000
# Name: total_bill, dtype: float64

# %%
# to_frame

group_df = df.groupby(['day'])["total_bill"].mean().to_frame("average_bill")

# %%
group_df
# Out:
#       average_bill
# day
# Thur     17.682742
# Fri      17.151579
# Sat      20.441379
# Sun      21.410000

# %%
#reset index

group_df.reset_index(inplace = True) #inplace= True then only resets in the actual df else it would just print the output
group_df
# Out:
#     day  average_bill
# 0  Thur     17.682742
# 1   Fri     17.151579
# 2   Sat     20.441379
# 3   Sun     21.410000

# %%
#sorting
group_df.sort_values(["average_bill"], ascending = False)
# Out:
#     day  average_bill
# 3   Sun     21.410000
# 2   Sat     20.441379
# 0  Thur     17.682742
# 1   Fri     17.151579

# %% [markdown]
# ##### Questions

# %% [markdown]
# ###### Find average tip for each night of the week

# %%
avg_tip_per_night = df.groupby(['day', 'time'])['tip'].mean().to_frame()
avg_tip_per_night
# Out:
#                   tip
# day  time
# Thur Lunch   2.767705
#      Dinner  3.000000
# Fri  Lunch   2.382857
#      Dinner  2.940000
# Sat  Lunch        NaN
#      Dinner  2.993103
# Sun  Lunch        NaN
#      Dinner  3.255132

# %%
#flatten the multiIndex DF
avg_tip_per_night.reset_index(inplace= True)
avg_tip_per_night
# Out:
#     day    time       tip
# 0  Thur   Lunch  2.767705
# 1  Thur  Dinner  3.000000
# 2   Fri   Lunch  2.382857
# 3   Fri  Dinner  2.940000
# 4   Sat   Lunch       NaN
# 5   Sat  Dinner  2.993103
# 6   Sun   Lunch       NaN
# 7   Sun  Dinner  3.255132

# %%
avg_tip_per_night[avg_tip_per_night['time']=='Dinner']
# Out:
#     day    time       tip
# 1  Thur  Dinner  3.000000
# 3   Fri  Dinner  2.940000
# 5   Sat  Dinner  2.993103
# 7   Sun  Dinner  3.255132

# %% [markdown]
# ##### Find max tip for each group of size

# %%
df.groupby('size')['tip'].max().to_frame("max_tip")
# Out:
#       max_tip
# size
# 1        1.92
# 2        5.85
# 3       10.00
# 4        9.00
# 5        5.14
# 6        6.70

# %% [markdown]
# ##### Top 10% of tips each day

# %%
df.groupby('day')['tip'].quantile(0.9)
# Out:
# day
# Thur    4.920
# Fri     4.060
# Sat     4.802
# Sun     5.035
# Name: tip, dtype: float64

# %%
df.groupby('day')['tip'].median()
# Out:
# day
# Thur    2.305
# Fri     3.000
# Sat     2.750
# Sun     3.150
# Name: tip, dtype: float64

# %%
sns.kdeplot(data=df, x='tip', hue="day")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Density'>

# %% [markdown]
# #### Aggregation on multiple columns

# %%
df.groupby("day")[['total_bill', 'tip']].mean()
# Out:
#       total_bill       tip
# day
# Thur   17.682742  2.771452
# Fri    17.151579  2.734737
# Sat    20.441379  2.993103
# Sun    21.410000  3.255132

# %%
df.groupby(['day', 'size'])[['total_bill', 'tip']].mean()
# Out:
#            total_bill       tip
# day  size
# Thur 1      10.070000  1.830000
#      2      15.156875  2.442500
#      3      19.160000  2.692500
#      4      29.950000  4.218000
#      5      41.190000  5.000000
#      6      30.383333  5.300000
# Fri  1       8.580000  1.920000
#      2      16.321875  2.644375
#      3      15.980000  3.000000
#      4      40.170000  4.730000
#      5            NaN       NaN
#      6            NaN       NaN
# Sat  1       5.160000  1.000000
#      2      16.837170  2.517547
#      3      25.509444  3.797778
#      4      29.876154  4.123846
#      5      28.150000  3.000000
#      6            NaN       NaN
# Sun  1            NaN       NaN
#      2      17.560000  2.816923
#      3      22.184000  3.120667
#      4      26.688333  4.087778
#      5      27.000000  4.046667
#      6      48.170000  5.000000

# %%
df.groupby(['day', 'size'])[['total_bill', 'tip']].mean().unstack().fillna(0).stack()
# Out:
#            total_bill       tip
# day  size
# Thur 1      10.070000  1.830000
#      2      15.156875  2.442500
#      3      19.160000  2.692500
#      4      29.950000  4.218000
#      5      41.190000  5.000000
#      6      30.383333  5.300000
# Fri  1       8.580000  1.920000
#      2      16.321875  2.644375
#      3      15.980000  3.000000
#      4      40.170000  4.730000
#      5       0.000000  0.000000
#      6       0.000000  0.000000
# Sat  1       5.160000  1.000000
#      2      16.837170  2.517547
#      3      25.509444  3.797778
#      4      29.876154  4.123846
#      5      28.150000  3.000000
#      6       0.000000  0.000000
# Sun  1       0.000000  0.000000
#      2      17.560000  2.816923
#      3      22.184000  3.120667
#      4      26.688333  4.087778
#      5      27.000000  4.046667
#      6      48.170000  5.000000

# %% [markdown]
# #### Transform

# %% [markdown]
# Transform merges the grouped df with the target df

# %%
df.groupby('day')['tip'].mean()
# Out:
# day
# Thur    2.771452
# Fri     2.734737
# Sat     2.993103
# Sun     3.255132
# Name: tip, dtype: float64

# %%
df.groupby('day')['tip'].transform('mean')
# Out:
# 0      3.255132
# 1      3.255132
# 2      3.255132
# 3      3.255132
# 4      3.255132
#          ...
# 239    2.993103
# 240    2.993103
# 241    2.993103
# 242    2.993103
# 243    2.771452
# Name: tip, Length: 244, dtype: float64

# %%
df['mean_tip'] = df.groupby('day')['tip'].transform('mean')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  percentage  mean_tip
# 0         16.99  1.01  Female     No   Sun  Dinner     2    5.944673  3.255132
# 1         10.34  1.66    Male     No   Sun  Dinner     3   16.054159  3.255132
# 2         21.01  3.50    Male     No   Sun  Dinner     3   16.658734  3.255132
# 3         23.68  3.31    Male     No   Sun  Dinner     2   13.978041  3.255132
# 4         24.59  3.61  Female     No   Sun  Dinner     4   14.680765  3.255132
# ..          ...   ...     ...    ...   ...     ...   ...         ...       ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3   20.392697  2.993103
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2    7.358352  2.993103
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2    8.822232  2.993103
# 242       17.82  1.75    Male     No   Sat  Dinner     2    9.820426  2.993103
# 243       18.78  3.00  Female     No  Thur  Dinner     2   15.974441  2.771452
#
# [244 rows x 9 columns]

# %% [markdown]
# #### IF U WANT TO USE BOOLEAN EXPRESSION IN PYTHON THEN USE .QUERY

# %%
df[df['size']==2]
# Out:
#      total_bill   tip     sex smoker   day    time  size  percentage  mean_tip
# 0         16.99  1.01  Female     No   Sun  Dinner     2    5.944673  3.255132
# 3         23.68  3.31    Male     No   Sun  Dinner     2   13.978041  3.255132
# 6          8.77  2.00    Male     No   Sun  Dinner     2   22.805017  3.255132
# 8         15.04  1.96    Male     No   Sun  Dinner     2   13.031915  3.255132
# 9         14.78  3.23    Male     No   Sun  Dinner     2   21.853857  3.255132
# ..          ...   ...     ...    ...   ...     ...   ...         ...       ...
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2    3.563814  2.993103
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2    7.358352  2.993103
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2    8.822232  2.993103
# 242       17.82  1.75    Male     No   Sat  Dinner     2    9.820426  2.993103
# 243       18.78  3.00  Female     No  Thur  Dinner     2   15.974441  2.771452
#
# [156 rows x 9 columns]

# %%
df.query('size == 2')
# Out:
#      total_bill   tip     sex smoker   day    time  size  percentage  mean_tip
# 0         16.99  1.01  Female     No   Sun  Dinner     2    5.944673  3.255132
# 3         23.68  3.31    Male     No   Sun  Dinner     2   13.978041  3.255132
# 6          8.77  2.00    Male     No   Sun  Dinner     2   22.805017  3.255132
# 8         15.04  1.96    Male     No   Sun  Dinner     2   13.031915  3.255132
# 9         14.78  3.23    Male     No   Sun  Dinner     2   21.853857  3.255132
# ..          ...   ...     ...    ...   ...     ...   ...         ...       ...
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2    3.563814  2.993103
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2    7.358352  2.993103
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2    8.822232  2.993103
# 242       17.82  1.75    Male     No   Sat  Dinner     2    9.820426  2.993103
# 243       18.78  3.00  Female     No  Thur  Dinner     2   15.974441  2.771452
#
# [156 rows x 9 columns]

# %%
df.query('tip >= mean_tip')
# Out:
#      total_bill   tip     sex smoker   day    time  size  percentage  mean_tip
# 2         21.01  3.50    Male     No   Sun  Dinner     3   16.658734  3.255132
# 3         23.68  3.31    Male     No   Sun  Dinner     2   13.978041  3.255132
# 4         24.59  3.61  Female     No   Sun  Dinner     4   14.680765  3.255132
# 5         25.29  4.71    Male     No   Sun  Dinner     4   18.623962  3.255132
# 11        35.26  5.00  Female     No   Sun  Dinner     4   14.180374  3.255132
# ..          ...   ...     ...    ...   ...     ...   ...         ...       ...
# 232       11.61  3.39    Male     No   Sat  Dinner     2   29.198966  2.993103
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2   19.317450  2.993103
# 238       35.83  4.67  Female     No   Sat  Dinner     3   13.033771  2.993103
# 239       29.03  5.92    Male     No   Sat  Dinner     3   20.392697  2.993103
# 243       18.78  3.00  Female     No  Thur  Dinner     2   15.974441  2.771452
#
# [112 rows x 9 columns]

# %%
df[df['tip']>df['mean_tip']]
# Out:
#      total_bill   tip     sex smoker   day    time  size  percentage  mean_tip
# 2         21.01  3.50    Male     No   Sun  Dinner     3   16.658734  3.255132
# 3         23.68  3.31    Male     No   Sun  Dinner     2   13.978041  3.255132
# 4         24.59  3.61  Female     No   Sun  Dinner     4   14.680765  3.255132
# 5         25.29  4.71    Male     No   Sun  Dinner     4   18.623962  3.255132
# 11        35.26  5.00  Female     No   Sun  Dinner     4   14.180374  3.255132
# ..          ...   ...     ...    ...   ...     ...   ...         ...       ...
# 232       11.61  3.39    Male     No   Sat  Dinner     2   29.198966  2.993103
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2   19.317450  2.993103
# 238       35.83  4.67  Female     No   Sat  Dinner     3   13.033771  2.993103
# 239       29.03  5.92    Male     No   Sat  Dinner     3   20.392697  2.993103
# 243       18.78  3.00  Female     No  Thur  Dinner     2   15.974441  2.771452
#
# [112 rows x 9 columns]

# %%
df[df.tip > df.mean_tip]
# Out:
#      total_bill   tip     sex smoker   day    time  size  percentage  mean_tip
# 2         21.01  3.50    Male     No   Sun  Dinner     3   16.658734  3.255132
# 3         23.68  3.31    Male     No   Sun  Dinner     2   13.978041  3.255132
# 4         24.59  3.61  Female     No   Sun  Dinner     4   14.680765  3.255132
# 5         25.29  4.71    Male     No   Sun  Dinner     4   18.623962  3.255132
# 11        35.26  5.00  Female     No   Sun  Dinner     4   14.180374  3.255132
# ..          ...   ...     ...    ...   ...     ...   ...         ...       ...
# 232       11.61  3.39    Male     No   Sat  Dinner     2   29.198966  2.993103
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2   19.317450  2.993103
# 238       35.83  4.67  Female     No   Sat  Dinner     3   13.033771  2.993103
# 239       29.03  5.92    Male     No   Sat  Dinner     3   20.392697  2.993103
# 243       18.78  3.00  Female     No  Thur  Dinner     2   15.974441  2.771452
#
# [112 rows x 9 columns]

# %% [markdown]
# #### lambda function on grp by

# %%
# z score on enitre dataset

df['zscore'] = (df['total_bill'] - df['total_bill'].mean())/df['total_bill'].std()
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  percentage  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2    5.944673
# 1         10.34  1.66    Male     No   Sun  Dinner     3   16.054159
# 2         21.01  3.50    Male     No   Sun  Dinner     3   16.658734
# 3         23.68  3.31    Male     No   Sun  Dinner     2   13.978041
# 4         24.59  3.61  Female     No   Sun  Dinner     4   14.680765
# ..          ...   ...     ...    ...   ...     ...   ...         ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3   20.392697
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2    7.358352
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2    8.822232
# 242       17.82  1.75    Male     No   Sat  Dinner     2    9.820426
# 243       18.78  3.00  Female     No  Thur  Dinner     2   15.974441
#
#      mean_tip    zscore
# 0    3.255132 -0.314066
# 1    3.255132 -1.061054
# 2    3.255132  0.137497
# 3    3.255132  0.437416
# ...

# %%
df["zscore_apply"] = df["total_bill"].apply(lambda x: (x- df["total_bill"].mean())/ df["total_bill"].std())
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  percentage  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2    5.944673
# 1         10.34  1.66    Male     No   Sun  Dinner     3   16.054159
# 2         21.01  3.50    Male     No   Sun  Dinner     3   16.658734
# 3         23.68  3.31    Male     No   Sun  Dinner     2   13.978041
# 4         24.59  3.61  Female     No   Sun  Dinner     4   14.680765
# ..          ...   ...     ...    ...   ...     ...   ...         ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3   20.392697
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2    7.358352
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2    8.822232
# 242       17.82  1.75    Male     No   Sat  Dinner     2    9.820426
# 243       18.78  3.00  Female     No  Thur  Dinner     2   15.974441
#
#      mean_tip    zscore  zscore_apply
# 0    3.255132 -0.314066     -0.314066
# 1    3.255132 -1.061054     -1.061054
# ...

# %%
df["zscore_wrt_dayGroup"] = df.groupby('day')["total_bill"].transform(lambda x: (x - x.mean())/x.std())
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  percentage  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2    5.944673
# 1         10.34  1.66    Male     No   Sun  Dinner     3   16.054159
# 2         21.01  3.50    Male     No   Sun  Dinner     3   16.658734
# 3         23.68  3.31    Male     No   Sun  Dinner     2   13.978041
# 4         24.59  3.61  Female     No   Sun  Dinner     4   14.680765
# ..          ...   ...     ...    ...   ...     ...   ...         ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3   20.392697
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2    7.358352
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2    8.822232
# 242       17.82  1.75    Male     No   Sat  Dinner     2    9.820426
# 243       18.78  3.00  Female     No  Thur  Dinner     2   15.974441
#
#      mean_tip    zscore  zscore_apply  zscore_wrt_dayGroup
# 0    3.255132 -0.314066     -0.314066            -0.500446
# ...

# %% [markdown]
# #### Apply()

# %%
df.groupby("day").apply(lambda x : (x.tip/ x.total_bill).mean())
# Out:
# day
# Thur    0.161276
# Fri     0.169913
# Sat     0.153152
# Sun     0.166897
# dtype: float64

# %%
x
# Out:
#       total_bill       tip       ans
# day
# Thur   17.682742  2.771452  0.156732
# Fri    17.151579  2.734737  0.159445
# Sat    20.441379  2.993103  0.146424
# Sun    21.410000  3.255132  0.152038
